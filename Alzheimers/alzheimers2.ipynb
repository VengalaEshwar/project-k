# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np

# %%
# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("keras_Model.h5", compile=False)

# Load the labels
with open("labels.txt", "r") as file:
    class_names = [line.strip() for line in file.readlines()]

# Function to preprocess the image
def preprocess_image(image_path, target_size=(224, 224)):
    """
    Preprocesses the image to the required format for the model.
    
    Parameters:
    - image_path: str, path to the image file.
    - target_size: tuple, target size for resizing the image.

    Returns:
    - np.array, preprocessed image ready for prediction.
    """
    # Load the image
    image = Image.open(image_path).convert("RGB")
    
    # Resize the image to the target size and crop from the center
    image = ImageOps.fit(image, target_size, Image.Resampling.LANCZOS)
    
    # Convert the image to a numpy array
    image_array = np.asarray(image)
    
    # Normalize the image
    normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1
    
    # Create a batch (batch size of 1)
    data = np.ndarray(shape=(1, target_size[0], target_size[1], 3), dtype=np.float32)
    data[0] = normalized_image_array
    
    return data

# Function to predict the class of a single image
def predict_image(image_path, model, class_labels):
    """
    Predicts the class of the given image using the loaded model.
    
    Parameters:
    - image_path: str, path to the image file.
    - model: Keras model, loaded model for prediction.
    - class_labels: list, list of class labels.

    Returns:
    - tuple, predicted class and confidence score.
    """
    # Preprocess the image
    data = preprocess_image(image_path)
    
    # Predict the class
    prediction = model.predict(data)
    index = np.argmax(prediction)
    class_name = class_labels[index]
    confidence_score = prediction[0][index]
    
    return class_name, confidence_score

# Example usage
image_path = '26(19).jpg'  # Replace with the path to your image
predicted_label, confidence = predict_image(image_path, model, class_names)
print(f'The predicted label for the image is: {predicted_label}')
print(f'Confidence Score: {confidence:.2f}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\ops\operation.py:208, in Operation.from_config(cls, config)
#     207 try:
# --> 208     return cls(**config)
#     209 except Exception as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\depthwise_conv2d.py:118, in DepthwiseConv2D.__init__(self, kernel_size, strides, padding, depth_multiplier, data_format, dilation_rate, activation, use_bias, depthwise_initializer, bias_initializer, depthwise_regularizer, bias_regularizer, activity_regularizer, depthwise_constraint, bias_constraint, **kwargs)
#      99 def __init__(
#     100     self,
#     101     kernel_size,
#    (...)
#     116     **kwargs
#     117 ):
# --> 118     super().__init__(
#     119         rank=2,
#     120         depth_multiplier=depth_multiplier,
#     121         kernel_size=kernel_size,
#     122         strides=strides,
#     123         padding=padding,
#     124         data_format=data_format,
#     125         dilation_rate=dilation_rate,
#     126         activation=activation,
#     127         use_bias=use_bias,
#     128         depthwise_initializer=depthwise_initializer,
#     129         bias_initializer=bias_initializer,
#     130         depthwise_regularizer=depthwise_regularizer,
#     131         bias_regularizer=bias_regularizer,
#     132         activity_regularizer=activity_regularizer,
#     133         depthwise_constraint=depthwise_constraint,
#     134         bias_constraint=bias_constraint,
#     135         **kwargs
#     136     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_depthwise_conv.py:106, in BaseDepthwiseConv.__init__(self, rank, depth_multiplier, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, depthwise_initializer, bias_initializer, depthwise_regularizer, bias_regularizer, activity_regularizer, depthwise_constraint, bias_constraint, trainable, name, **kwargs)
#      84 def __init__(
#      85     self,
#      86     rank,
#    (...)
#     104     **kwargs,
#     105 ):
# --> 106     super().__init__(
#     107         trainable=trainable,
#     108         name=name,
#     109         activity_regularizer=regularizers.get(activity_regularizer),
#     110         **kwargs,
#     111     )
#     112     self.rank = rank
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\layer.py:263, in Layer.__init__(self, activity_regularizer, trainable, dtype, autocast, name, **kwargs)
#     262 if kwargs:
# --> 263     raise ValueError(
#     264         "Unrecognized keyword arguments "
#     265         f"passed to {self.__class__.__name__}: {kwargs}"
#     266     )
#     268 self.built = False
#
# ValueError: Unrecognized keyword arguments passed to DepthwiseConv2D: {'groups': 1}
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 np.set_printoptions(suppress=True)
#       4 # Load the model
# ----> 5 model = load_model("keras_Model.h5", compile=False)
#       7 # Load the labels
#       8 with open("labels.txt", "r") as file:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\saving\saving_api.py:183, in load_model(filepath, custom_objects, compile, safe_mode)
#     176     return saving_lib.load_model(
#     177         filepath,
#     178         custom_objects=custom_objects,
#     179         compile=compile,
#     180         safe_mode=safe_mode,
#     181     )
#     182 if str(filepath).endswith((".h5", ".hdf5")):
# --> 183     return legacy_h5_format.load_model_from_hdf5(filepath)
#     184 elif str(filepath).endswith(".keras"):
#     185     raise ValueError(
#     186         f"File not found: filepath={filepath}. "
#     187         "Please ensure the file is an accessible `.keras` "
#     188         "zip file."
#     189     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\legacy\saving\legacy_h5_format.py:133, in load_model_from_hdf5(filepath, custom_objects, compile)
#     130 model_config = json_utils.decode(model_config)
#     132 with saving_options.keras_option_scope(use_legacy_config=True):
# --> 133     model = saving_utils.model_from_config(
#     134         model_config, custom_objects=custom_objects
#     135     )
#     137     # set weights
#     138     load_weights_from_hdf5_group(f["model_weights"], model)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\legacy\saving\saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\legacy\saving\serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\models\sequential.py:330, in Sequential.from_config(cls, config, custom_objects)
#     326 for layer_config in layer_configs:
#     327     if "module" not in layer_config:
#     328         # Legacy format deserialization (no "module" key)
#     329         # used for H5 and SavedModel formats
# --> 330         layer = saving_utils.model_from_config(
#     331             layer_config,
#     332             custom_objects=custom_objects,
#     333         )
#     334     else:
#     335         layer = serialization_lib.deserialize_keras_object(
#     336             layer_config,
#     337             custom_objects=custom_objects,
#     338         )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\legacy\saving\saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\legacy\saving\serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\models\sequential.py:330, in Sequential.from_config(cls, config, custom_objects)
#     326 for layer_config in layer_configs:
#     327     if "module" not in layer_config:
#     328         # Legacy format deserialization (no "module" key)
#     329         # used for H5 and SavedModel formats
# --> 330         layer = saving_utils.model_from_config(
#     331             layer_config,
#     332             custom_objects=custom_objects,
#     333         )
#     334     else:
#     335         layer = serialization_lib.deserialize_keras_object(
#     336             layer_config,
#     337             custom_objects=custom_objects,
#     338         )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\legacy\saving\saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\legacy\saving\serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\models\model.py:513, in Model.from_config(cls, config, custom_objects)
#     508 if is_functional_config and revivable_as_functional:
#     509     # Revive Functional model
#     510     # (but not Functional subclasses with a custom __init__)
#     511     from keras.src.models.functional import functional_from_config
# --> 513     return functional_from_config(
#     514         cls, config, custom_objects=custom_objects
#     515     )
#     517 # Either the model has a custom __init__, or the config
#     518 # does not contain all the information necessary to
#     519 # revive a Functional model. This happens when the user creates
#    (...)
#     522 # In this case, we fall back to provide all config into the
#     523 # constructor of the class.
#     524 try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\models\functional.py:514, in functional_from_config(cls, config, custom_objects)
#     512 # First, we create all layers and enqueue nodes to be processed
#     513 for layer_data in config["layers"]:
# --> 514     process_layer(layer_data)
#     516 # Then we process nodes in order of layer depth.
#     517 # Nodes that cannot yet be processed (if the inbound node
#     518 # does not yet exist) are re-enqueued, and the process
#     519 # is repeated until all nodes are processed.
#     520 while unprocessed_nodes:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\models\functional.py:494, in functional_from_config.<locals>.process_layer(layer_data)
#     490 # Instantiate layer.
#     491 if "module" not in layer_data:
#     492     # Legacy format deserialization (no "module" key)
#     493     # used for H5 and SavedModel formats
# --> 494     layer = saving_utils.model_from_config(
#     495         layer_data, custom_objects=custom_objects
#     496     )
#     497 else:
#     498     layer = serialization_lib.deserialize_keras_object(
#     499         layer_data, custom_objects=custom_objects
#     500     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\legacy\saving\saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\legacy\saving\serialization.py:504, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     502     else:
#     503         with object_registration.CustomObjectScope(custom_objects):
# --> 504             deserialized_obj = cls.from_config(cls_config)
#     505 else:
#     506     # Then `cls` may be a function returning a class.
#     507     # in this case by convention `config` holds
#     508     # the kwargs of the function.
#     509     custom_objects = custom_objects or {}
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\ops\operation.py:210, in Operation.from_config(cls, config)
#     208     return cls(**config)
#     209 except Exception as e:
# --> 210     raise TypeError(
#     211         f"Error when deserializing class '{cls.__name__}' using "
#     212         f"config={config}.\n\nException encountered: {e}"
#     213     )
#
# TypeError: Error when deserializing class 'DepthwiseConv2D' using config={'name': 'expanded_conv_depthwise', 'trainable': True, 'dtype': 'float32', 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'linear', 'use_bias': False, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'bias_regularizer': None, 'activity_regularizer': None, 'bias_constraint': None, 'depth_multiplier': 1, 'depthwise_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'depthwise_regularizer': None, 'depthwise_constraint': None}.
#
# Exception encountered: Unrecognized keyword arguments passed to DepthwiseConv2D: {'groups': 1}

# %%
pip install --upgrade tensorflow keras
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (2.16.1)
# Requirement already satisfied: keras in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (3.2.1)
# Collecting keras
#   Downloading keras-3.3.3-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: rich in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from keras) (0.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from rich->keras) (2.17.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\t.tejaswini\appdata\roaming\python\python312\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.5)
# Downloading keras-3.3.3-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.1 MB 1.7 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.2/1.1 MB 1.7 MB/s eta 0:00:01
#    --------- ------------------------------ 0.3/1.1 MB 1.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.5/1.1 MB 2.6 MB/s eta 0:00:01
#    ------------------------- -------------- 0.7/1.1 MB 3.2 MB/s eta 0:00:01
#    -------------------------------- ------- 0.9/1.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 3.4 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.2.1
#     Uninstalling keras-3.2.1:
#       Successfully uninstalled keras-3.2.1
# Successfully installed keras-3.3.3

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
import matplotlib.pyplot as plt
import numpy as np
import cv2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
#       2 from tensorflow.keras.models import Sequential, load_model
#       3 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\_tf_keras\keras\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.api import activations
#       8 from keras.api import applications
#       9 from keras.api import callbacks
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\api\__init__.py:16
#      14 from keras.api import datasets
#      15 from keras.api import distribution
# ---> 16 from keras.api import dtype_policies
#      17 from keras.api import export
#      18 from keras.api import initializers
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\api\dtype_policies\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.dtype_policies import deserialize
#       8 from keras.src.dtype_policies import get
#       9 from keras.src.dtype_policies import serialize
#
# ImportError: cannot import name 'deserialize' from 'keras.src.dtype_policies' (C:\Users\T.Tejaswini\AppData\Roaming\Python\Python312\site-packages\keras\src\dtype_policies\__init__.py)

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
import cv2  # Install opencv-python
import numpy as np
